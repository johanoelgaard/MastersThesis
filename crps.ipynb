# %%
import os
import pandas as pd
import gc

# %%
# # save as parquet for easier use later
# # get list of files in directory
# files = os.listdir('/Users/johan/Downloads/crspdata_sas/ihz202412_sas')

# # get list of filenames without extensions
# filenames = [file.split('.')[0] for file in files]

# # convert all files to parquet
# for filename in filenames:
#     filespath = f'/Users/johan/Downloads/crspdata_sas/ihz202412_sas/{filename}.sas7bdat'
#     savepath = f'/Users/johan/Downloads/crspdata/{filename}.parquet'
    
#     # read and process the file
#     df = pd.read_sas(filespath, format='sas7bdat', encoding='utf-8')
#     df.to_parquet(savepath, index=False)
    
#     # delete the DataFrame and run garbage collection
#     del df
#     gc.collect()

# %%
parquet_files = os.listdir('/Users/johan/Downloads/crspdata')
print(parquet_files)
# Out:
# ['core.parquet', 'cap.parquet', 'esg.parquet', 'eod_esg.parquet', 'eod_cap.parquet', 'sector.parquet', 'eod_core.parquet', 'eod_vg.parquet', 'eod_sector.parquet', 'vg.parquet']

# %%
filename = 'sector'
filespath = f'/Users/johan/Downloads/crspdata/{filename}.parquet'
df = pd.read_parquet(filespath)
display(df)
# Out:
#                   TRADETSTMP      CRSPRE1      CRSPEN1      CRSPMT1  \
# 0        2012-09-21 09:30:00  1132.440050  1048.996259   975.135320
# 1        2012-09-21 09:30:01  1132.558955  1049.274149   975.539616
# 2        2012-09-21 09:30:02  1132.597057  1049.283637   975.710554
# 3        2012-09-21 09:30:03  1132.577618  1049.401445   975.744429
# 4        2012-09-21 09:30:04  1132.609944  1049.441034   975.777756
# ...                      ...          ...          ...          ...
# 71959883 2024-12-31 15:59:56  1750.656279  1182.546032  2005.229096
# 71959884 2024-12-31 15:59:57  1750.671630  1182.514256  2005.185964
# 71959885 2024-12-31 15:59:58  1750.652272  1182.549501  2005.153258
# 71959886 2024-12-31 15:59:59  1750.660348  1182.599613  2005.291199
# 71959887 2024-12-31 16:00:00  1750.560778  1182.667599  2005.352549
#
#               CRSPID1      CRSPCS1      CRSPHC1      CRSPCD1      CRSPTE1  \
# 0         1041.028205  1094.520657  1139.360010  1163.575988  1309.017060
# ...
